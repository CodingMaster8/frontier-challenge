# %%
from frontier_challenge.tools import CNPJLookupTool

import logging

# Configure logging to display in Jupyter
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    force=True  # This overrides any existing configuration
)

# %%
tool = CNPJLookupTool(db_path="../data/br_funds.db")

# %%
result = tool.lookup_by_cnpj("look for [55.533.539/0001-06, 00.416.515/0001-70, 12.345.678/0001-90] in the database")

# %%
print(result)
